# %% [markdown]
# # Problem 1
# ### Analysts are required to explore data and reflect on the insights. Clear writing skill is an integral part of a good report. Note that the explanations must be such that readers with minimum knowledge of analytics is able to grasp the insight.
#
# ### Austo Motor Company is a leading car manufacturer specializing in SUV, Sedan, and Hatchback models. In its recent board meeting, concerns were raised by the members on the efficiency of the marketing campaign currently being used.The board decides to rope in an analytics professional to improve the existing campaign.
#
# ### 1.You as an analyst have been tasked with performing a thorough analysis of the data and coming up with insights to improve the marketing campaign.

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import copy

# %%
#loading the problem 1 csv file of austo_automobile.csv into the jupyter notebook
df = pd.read_csv("austo_automobile.csv")

# %%
#printing last 10 rows
df.tail(10)
# Out:
#       Age Gender Profession Marital_status Education  No_of_Dependents  \
# 1571   22   Male   Business        Married  Graduate                 3
# 1572   22   Male   Business         Single  Graduate                 2
# 1573   22   Male   Business        Married  Graduate                 3
# 1574   22   Male   Salaried        Married  Graduate                 3
# 1575   22   Male   Salaried        Married  Graduate                 3
# 1576   22   Male   Salaried         Single  Graduate                 2
# 1577   22   Male   Business        Married  Graduate                 4
# 1578   22   Male   Business         Single  Graduate                 2
# 1579   22   Male   Business        Married  Graduate                 3
# 1580   22   Male   Salaried        Married  Graduate                 4
#
#      Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 1571            No         No              No   36000        0.000000
# ...

# %% [markdown]
# ## Q.A. What is the important technical information about the dataset that a database administrator would be interested in?
# ### Answer : A database administrator would be interested in the size of the dataset and nature of the variables in the dataset.
# ### The size of the dataset can be identifed as the size of the rows and columns of the dataset as how many number of rows and columns are present in the dataset.Similarly the nature of the variables can be identifed as each row or column has a individual nature such as object,numeric etc.

# %% [markdown]
# Nature of the variables

# %%
#finding  the nature of the variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.0+ KB

# %% [markdown]
# Type of dataset

# %%
#finding the type of the dataset
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
Size of the dataset

# %%
#finding the size of the dataset
df.size
# Out:
# 22134

# %% [markdown]
# Shape of dataset

# %%
#finding the shape of the dataset
print("no. of rows: ",df.shape[0], "\n""no. of columns: ",df.shape[1])
# Out:
# no. of rows:  1581
# no. of columns:  14

# %% [markdown]
# ## Q.B. Take a critical look at the data and do a preliminary analysis of the variables. Do a quality check of the data so that the variables are consistent. Are there any discrepancies present in the data?

# %% [markdown]
# ### Preliminary analysis of the data
# #### Step 1 : Dataset analysis
# First of all, let’s see what we have in the dataset.

# %%
list(df)
# Out:
# ['Age',
#  'Gender',
#  'Profession',
#  'Marital_status',
#  'Education',
#  'No_of_Dependents',
#  'Personal_loan',
#  'House_loan',
#  'Partner_working',
#  'Salary',
#  'Partner_salary',
#  'Total_salary',
#  'Price',
#  'Make']

# %% [markdown]
# #### Step 2 : Analysis questions
# To perform a preliminary analysis, we should outline a set of questions that we want to answer as a result of our analysis.
# 1.what is the highest making vehicle?
# 2.Which vehicle makes the most price?
# 3.Is there any relationship between marital_status and no of dependants?
# 4.Which gender has the highest profession at the certain age count?

# %% [markdown]
# ### 1.what is the highest making vehicle?

# %%
sns.histplot(data=df, x='Make', kde=True);

# %% [markdown]
# ### Observation :
# From the above graph we can say that the Sedan vehicle is the highest.

# %% [markdown]
# ### 2.Which vehicle makes the most price?

# %%
sns.barplot(data=df, x='Make', y='Price') ;

# %% [markdown]
# ### Observation:
# Suv vehicle makes the highest price above the range of 50,000

# %% [markdown]
# ### 3.Is there any relationship between marital_status and no of dependants?

# %%
sns.lineplot(data = df , x = 'Marital_status' , y = 'No_of_Dependents');

# %% [markdown]
# ### Observation :
# Yes,there is a relationship between the Marital_status and No_of_Dependents.
# The no of dependents are more for the married persons than the single persons.
# It has a declining rate from married  to single.

# %% [markdown]
# ### 4.Which gender has the highest profession at the certain age count?

# %%
sns.lineplot(data=df,x = 'Age' , y = 'Gender', ci = False ,hue='Profession');

# %% [markdown]
# ### Observation :
# The male has highest both Business and salaried professions at the below age of 25

# %% [markdown]
# ### Data quality check :
# #### Step 1 :
# printing top 5 rows

# %%
df.head()
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %% [markdown]
# #### Shape of the dataset

# %%
df.shape
# Out:
# (1581, 14)

# %% [markdown]
# #### Checking Index

# %%
# Check the index 
df.index.values
# Out:
# array([   0,    1,    2, ..., 1578, 1579, 1580], dtype=int64)

# %%
#check the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.0+ KB

# %% [markdown]
# #### Step 2: Treating Bad Data

# %%
df['Gender'].unique()
# Out:
# array(['Male', nan, 'Female', 'Femle'], dtype=object)

# %% [markdown]
# #### Checking null values if any

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['Partner_salary'].unique()
# Out:
# array([70700., 70300., 60700., 60200., 60500., 50800., 40400.,     0.,
#        70600., 60600., 60300., 45500., 40200., 40700.,   600.,   700.,
#        27800., 70000., 40100., 40900., 27000.,    nan, 40500., 50400.,
#        80400., 60900., 60100., 70200., 30000., 40300., 40800., 70800.,
#          900., 45000., 40600., 50700., 80500., 27700., 35800., 26600.,
#        60000., 27900., 60800., 40000., 70100., 38100., 38200., 30200.,
#        38500., 50900., 35100., 38700., 38300., 38900., 23200., 24700.,
#        30800., 28100., 38400., 38000., 23100., 30100., 25700., 70400.,
#          200., 30900., 26100., 45700.,   400., 28200., 70900., 38800.,
#        45200., 26800., 60400., 30300., 25800.,   800., 38600., 24500.,
#        30700., 28500., 24900., 70500., 35900., 30500., 28900., 27200.,
#        45900., 25300., 35600., 25000., 25200., 26300., 35700., 23800.,
#        32700., 30600., 45600., 28000., 32600., 28600., 25100., 26700.,
# ...

# %%
df[df['Age'] < 30]
# Out:
#       Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 740    29   Male   Business        Married  Post Graduate                 2
# 741    29   Male   Business        Married  Post Graduate                 3
# 742    29   Male   Business        Married  Post Graduate                 2
# 743    29   Male   Salaried        Married  Post Graduate                 3
# 744    29   Male   Salaried        Married  Post Graduate                 4
# ...   ...    ...        ...            ...            ...               ...
# 1576   22   Male   Salaried         Single       Graduate                 2
# 1577   22   Male   Business        Married       Graduate                 4
# 1578   22   Male   Business         Single       Graduate                 2
# 1579   22   Male   Business        Married       Graduate                 3
# 1580   22   Male   Salaried        Married       Graduate                 4
#
# ...

# %% [markdown]
# #### Step 3 : Treat Missing Values

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender               54
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
df.Partner_salary=df.Partner_salary.fillna(df.Partner_salary.mean())

# %%
df.isnull().sum()
# Out:
# Age                  0
# Gender              54
# Profession           0
# Marital_status       0
# Education            0
# No_of_Dependents     0
# Personal_loan        0
# House_loan           0
# Partner_working      0
# Salary               0
# Partner_salary       0
# Total_salary         0
# Price                0
# Make                 0
# dtype: int64

# %%
df['Gender'] = df['Gender'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %% [markdown]
# #### Step 4 : Checking for duplicate values

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 0

# %% [markdown]
# #### As there are no duplicates there are no discrepancies present in the data

# %% [markdown]
# ## Q.C Explore all the features of the data separately by using appropriate visualizations and draw insights that can be utilized by the business.

# %% [markdown]
# #### Univariate Analysis

# %%
df[['Salary','Partner_salary']].describe()
# Out:
#              Salary  Partner_salary
# count   1581.000000     1581.000000
# mean   60392.220114    20225.559322
# std    14674.825044    18905.183912
# min    30000.000000        0.000000
# 25%    51900.000000        0.000000
# 50%    59500.000000    24900.000000
# 75%    71800.000000    38000.000000
# max    99300.000000    80500.000000

# %% [markdown]
# ##### Insights:
# ###### The salary of working person ranges from minimum of 30k to the maximum of 99k
# ###### Mean of Salary is higher than Partner_salary which means the Total_salary has the majority of Salary rather than Partner_salary

# %%
fig, axes = plt.subplots(nrows=2,ncols=2)
fig.set_size_inches(10,8)
sns.histplot(df['Salary'], kde=True, ax=axes[0][0])
sns.boxplot(x='Salary', data=df, ax=axes[0][1])
sns.histplot(df['Partner_salary'] , kde=True, ax=axes[1][0])
sns.boxplot(x='Partner_salary', data=df , ax=axes[1][1])
plt.show()

# %% [markdown]
# ##### Insights:
# ###### Both Salary and Partner_salary does not have any outliers

# %% [markdown]
# #### Categorical Variable

# %%
df['Make'].value_counts(normalize=True)
# Out:
# Sedan        0.444023
# Hatchback    0.368121
# SUV          0.187856
# Name: Make, dtype: float64

# %%
sns.countplot(x='Make', data=df, palette='pastel',hue = 'Profession')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %% [markdown]
# ##### Insights:
# ###### 1.Sedan has the highest making count.
# ###### 2.Salaried people has the highesh cars than Business people for both SUV and Sedan vehicles.
# ###### 3.Both Business and Salaried persons have equal Hatchback vehicles.

# %% [markdown]
# #### Bivariate Analysis

# %% [markdown]
# ###### Numeric vs Numeric

# %%
plt.scatter(df['Salary'],df['Partner_salary'])

# %%
plt.scatter(df['Total_salary'],df['Price'])

# %% [markdown]
# ### Insights:
# salary and partner salary doesnot have a pattern of increasing or decreasing which results in non indentification of relationship
# Total salary and price has a pattern of increasing range from 40k to 140k which results in mild identification of a positive relationship.

# %% [markdown]
# #### Categorical vs Categorical
# 1.For Gender and profession

# %%
sns.countplot(x='Gender', hue='Profession', data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
pd.crosstab(df['Gender'], df['Profession'], margins=True, normalize = True)
# Out:
# Profession  Business  Salaried       All
# Gender
# 0           0.013283  0.020873  0.034156
# Female      0.065781  0.141050  0.206831
# Femle       0.000633  0.000000  0.000633
# Male        0.353574  0.404807  0.758381
# All         0.433270  0.566730  1.000000

# %% [markdown]
# #### Insights :
# ##### Here from the above plot the male salaried person has the highest rate of count.

# %% [markdown]
# For the Education and Personal_loan.

# %%
sns.countplot(x='Education', hue='Personal_loan', data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
pd.crosstab(df['Education'], df['Personal_loan'], margins=True, normalize = True)
# Out:
# Personal_loan        No       Yes       All
# Education
# Graduate       0.182163  0.194813  0.376977
# Post Graduate  0.316888  0.306135  0.623023
# All            0.499051  0.500949  1.000000

# %% [markdown]
# #### Insights:
# ##### From the above plot post graduation people has most "Yes" personal loans but the graduate people has the least"Yes" personal loans.

# %% [markdown]
# For the Education and House_loan.

# %%
sns.countplot(x='Education', hue='House_loan', data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
pd.crosstab(df['Education'], df['House_loan'], margins=True, normalize = True)
# Out:
# House_loan           No       Yes       All
# Education
# Graduate       0.249209  0.127767  0.376977
# Post Graduate  0.417457  0.205566  0.623023
# All            0.666667  0.333333  1.000000

# %% [markdown]
# #### Insights:
# ##### From the above plot Post graduate people has a "yes" for the house_loan rather than the graduate people.

# %% [markdown]
# For the Make and Profession.

# %%
sns.countplot(x='Make', hue='Profession', data=df)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %%
pd.crosstab(df['Gender'], df['Make'], margins=True, normalize = True)
# Out:
# Make    Hatchback       SUV     Sedan       All
# Gender
# 0        0.001265  0.004428  0.028463  0.034156
# Female   0.009488  0.108159  0.089184  0.206831
# Femle    0.000000  0.000633  0.000000  0.000633
# Male     0.357369  0.074636  0.326376  0.758381
# All      0.368121  0.187856  0.444023  1.000000

# %% [markdown]
# #### Insights:
# ##### Salaried people has the highest Sedan vehicles and the Business people has the lowest suv vehicles.
# ##### similarly Business people has the highest Sedan vehicles and the Salaried people has the lowest suv vehicles.

# %% [markdown]
# #### Categorical vs Numeric

# %%
fig_dims = (12, 5)
sns.boxplot(x='Make', y='Price', data=df)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Price'>

# %% [markdown]
# ##### Insights:
# ###### Suv has an outlier
# ###### Hatchback has the low boxplot range

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,fmt=".2f");

# %% [markdown]
# ##### Insights:
# ###### The price has correlated with the Age.

# %% [markdown]
# ### Q.D.Understanding the relationships among the variables in the dataset is crucial for every analytical project. Perform analysis on the data fields to gain deeper insights. Comment on your understanding of the data.

# %% [markdown]
# Insight 1:

# %%
sns.barplot(data=df,x='Partner_working',y='Salary',hue = 'Profession')
# Out:
# <AxesSubplot:xlabel='Partner_working', ylabel='Salary'>

# %% [markdown]
# #### Insights:
# ##### The people who has the partners has the highest salary in the salaried profession.

# %% [markdown]
# Insight 2:

# %%
sns.lineplot(data=df,x='Make',y='Price',hue = 'Partner_working')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Price'>

# %% [markdown]
# #### Insights:
# ##### The people who has the partners has the highest price in the suv vehicles to buy.
# ##### The price is decreased from SUV vehicles to the Hatchback vehicles.
# ##### The Hatch back has the lowest price when there are no partners who are working.

# %% [markdown]
# Insight 3:

# %%
sns.scatterplot(data=df,x='Price',y='Make')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Make'>

# %% [markdown]
# #### Insights:
# ##### The SUV vehicle has the highest price of points.
# ##### The hatchback has the lowest price of points.

# %% [markdown]
# Insight 4 :

# %%
sns.histplot(x='Make', data=df)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Count'>

# %% [markdown]
# #### Insights:
# ##### SUV has the lowest making process.

# %%
### Data Preparation

# %%
#### Scaling

# %%
## Dropping the ID fearure before we scale numeric values as the same will not add any value in model building
df.drop(labels='Profession',axis=1,inplace=True)
df.head()
# Out:
#    Age  Gender Marital_status      Education  No_of_Dependents Personal_loan  \
# 0   53    Male        Married  Post Graduate                 4            No
# 1   53   Femal        Married  Post Graduate                 4           Yes
# 2   53  Female        Married  Post Graduate                 3            No
# 3   53  Female        Married       Graduate                 2           Yes
# 4   53    Male        Married  Post Graduate                 3            No
#
#   House_loan Partner_working  Salary  Partner_salary  Total_salary  Price Make
# 0         No             Yes   99300         70700.0        170000  61000  SUV
# 1         No             Yes   95500         70300.0        165800  61000  SUV
# 2         No             Yes   97300         60700.0        158000  57000  SUV
# 3         No             Yes   72500         70300.0        142800  61000  SUV
# 4         No             Yes   79700         60200.0        139900  57000  SUV

# %%
cat=[]
num=[]
for i in df.columns:
    if df[i].dtype=="object":
        cat.append(i)
    else:
        num.append(i)
print(cat) 
print(num)
# Out:
# ['Gender', 'Marital_status', 'Education', 'Personal_loan', 'House_loan', 'Partner_working', 'Make']
# ['Age', 'No_of_Dependents', 'Salary', 'Partner_salary', 'Total_salary', 'Price']

# %%
# Method 1
## Using Zscore for scaling/standardisation
from scipy.stats import zscore

# %%
data_scaled=df[num].apply(zscore)
data_scaled.head()
# Out:
#         Age  No_of_Dependents    Salary  Partner_salary  Total_salary  \
# 0  2.502317          1.634953  2.652167             NaN      3.538836
# 1  2.502317          1.634953  2.393138             NaN      3.374374
# 2  2.502317          0.574715  2.515836             NaN      3.068944
# 3  2.502317         -0.485523  0.825333             NaN      2.473747
# 4  2.502317          0.574715  1.316124             NaN      2.360190
#
#       Price
# 0  1.863796
# 1  1.863796
# 2  1.570311
# 3  1.863796
# 4  1.570311

# %%
df.describe()
# Out:
#                Age  No_of_Dependents        Salary  Partner_salary  \
# count  1581.000000       1581.000000   1581.000000     1475.000000
# mean     31.922201          2.457938  60392.220114    20225.559322
# std       8.425978          0.943483  14674.825044    19573.149277
# min      22.000000          0.000000  30000.000000        0.000000
# 25%      25.000000          2.000000  51900.000000        0.000000
# 50%      29.000000          2.000000  59500.000000    25600.000000
# 75%      38.000000          3.000000  71800.000000    38300.000000
# max      54.000000          4.000000  99300.000000    80500.000000
#
#         Total_salary         Price
# count    1581.000000   1581.000000
# mean    79625.996205  35597.722960
# std     25545.857768  13633.636545
# min     30000.000000  18000.000000
# 25%     60500.000000  25000.000000
# 50%     78000.000000  31000.000000
# 75%     95900.000000  47000.000000
# max    171000.000000  70000.000000

# %%
data_scaled.describe()
# Out:
#                 Age  No_of_Dependents        Salary  Partner_salary  \
# count  1.581000e+03      1.581000e+03  1.581000e+03             0.0
# mean  -9.314638e-15     -1.370609e-15 -1.596867e-16             NaN
# std    1.000316e+00      1.000316e+00  1.000316e+00             NaN
# min   -1.177945e+00     -2.605999e+00 -2.071700e+00             NaN
# 25%   -8.217908e-01     -4.855233e-01 -5.788762e-01             NaN
# 50%   -3.469183e-01     -4.855233e-01 -6.081861e-02             NaN
# 75%    7.215449e-01      5.747147e-01  7.776167e-01             NaN
# max    2.621035e+00      1.634953e+00  2.652167e+00             NaN
#
#        Total_salary         Price
# count  1.581000e+03  1.581000e+03
# mean   9.690751e-18  1.605083e-15
# std    1.000316e+00  1.000316e+00
# min   -1.943239e+00 -1.291166e+00
# 25%   -7.489296e-01 -7.775678e-01
# 50%   -6.367023e-02 -3.373405e-01
# 75%    6.372522e-01  8.365989e-01
# max    3.577994e+00  2.524137e+00

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)
fig.set_size_inches(10,5)
sns.histplot(df['Price'] , kde=True, ax=axes[0])
sns.histplot(data_scaled['Total_salary'] , kde=True, ax=axes[1])
plt.show()

# %%
# Method II
## Using standardScaler for Standardisation

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(df[num])
data_standard=scaler.transform(df[num])
data_standard=pd.DataFrame(data_standard, columns=df[num].columns)
data_standard.describe()
# Out:
#                 Age  No_of_Dependents        Salary  Partner_salary  \
# count  1.581000e+03      1.581000e+03  1.581000e+03    1.475000e+03
# mean  -9.314638e-15     -1.370609e-15 -1.596867e-16   -4.624549e-16
# std    1.000316e+00      1.000316e+00  1.000316e+00    1.000339e+00
# min   -1.177945e+00     -2.605999e+00 -2.071700e+00   -1.033682e+00
# 25%   -8.217908e-01     -4.855233e-01 -5.788762e-01   -1.033682e+00
# 50%   -3.469183e-01     -4.855233e-01 -6.081861e-02    2.746754e-01
# 75%    7.215449e-01      5.747147e-01  7.776167e-01    9.237436e-01
# max    2.621035e+00      1.634953e+00  2.652167e+00    3.080490e+00
#
#        Total_salary         Price
# count  1.581000e+03  1.581000e+03
# mean   9.690751e-18  1.605083e-15
# std    1.000316e+00  1.000316e+00
# min   -1.943239e+00 -1.291166e+00
# 25%   -7.489296e-01 -7.775678e-01
# 50%   -6.367023e-02 -3.373405e-01
# 75%    6.372522e-01  8.365989e-01
# max    3.577994e+00  2.524137e+00

# %% [markdown]
# #### Insights
# ##### Applying zscore or using StandardScalar give us the same results which means profession category doesnot get wheightage to decide whether buy with certain price of vehicles

# %% [markdown]
# ### Q.E. Employees working on the existing marketing campaign have made the following remarks. Based on the data and your analysis state whether you agree or disagree with their observations. Justify your answer Based on the data available.

# %% [markdown]
# #### E1) Steve Roger says “Men prefer SUV by a large margin, compared to the women”

# %%
sns.countplot(x='Make', data=df, palette='pastel',hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %% [markdown]
# #### Answer:
# ##### I dont agree with Steve Rogers beacuse as we can see from the above plot the blue margin indicates male which refers to the men.The blue margin is highest in the hatchback vehicle category,which means "Men prefers Hatchback by a large margin ,compared to the women.

# %% [markdown]
# #### E2) Ned Stark believes that a salaried person is more likely to buy a Sedan.

# %%
sns.countplot(x='Make', data=df, palette='pastel',hue = 'Profession')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %% [markdown]
# #### Answer :
# #### I agree with Ned Stark because as we can we see from the above plot the pink margin Indicates salaried.The pink margin is highest in the sedan vehicle category,which means " that a salaried person is more likely to buy a Sedan"

# %% [markdown]
# #### E3) Sheldon Cooper does not believe any of them; he claims that a salaried male is an easier target for a SUV sale over a Sedan Sale.

# %%
plt.figure(figsize = (15,7))
sns.lineplot(data = df , x = 'Make' , y = 'Profession', hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Profession'>

# %% [markdown]
# #### Answer :
# #### I partially agree with Sheldon Cooper because as we can we see from the above plot the blue line Indicates Male.The blue line is nearest to the SUV  vehicle category,which means "  that a salaried male maybe is an easier target for a SUV sale over a Sedan Sale."

# %% [markdown]
# #### Q.F. From the given data, comment on the amount spent on purchasing automobiles across the following categories. Comment on how a Business can utilize the results from this exercise. Give justification along with presenting metrics/charts used for arriving at the conclusions.

# %% [markdown]
# #### F1) Gender

# %%
sns.barplot(data=df,x='Gender',y='Price')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Price'>

# %% [markdown]
# #### Answer:
# #### Based on the above plot we can consider that the male has bought nearly over 30000 price and also female population has bought nearly above the 50000 price.But the highest price used for buying automobiles is the population of Femle category.Business can utilize as the interest of modifications and style of the product depends on the increasing of buyers will happen as the femle category is maybe interest in above categories of modification or style and the price rate of the automobile which results in the highest price of femle.

# %% [markdown]
# #### F2) Personal_loan

# %%
sns.barplot(data=df,x='Personal_loan',y='Price')
# Out:
# <AxesSubplot:xlabel='Personal_loan', ylabel='Price'>

# %% [markdown]
# #### Answer:
# #### Based on the above plot we can consider that people has personal loans which are in the range of 0 to 35000 and more people doesnot have personal loand that they have to pay above the 35000 price.If the people has the interest rate for having personal loan with minimum price of automobiles then the percentage of people taking personal loans for the price of automobiles to pay will be gradually increased.

# %% [markdown]
# ### Q.G.From the current data set comment if having a working partner leads to purchase of a higher priced car.

# %%
sns.barplot(data=df,x='Make',y='Price',hue = 'Partner_working')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Price'>

# %% [markdown]
# #### Answer:
# #### From the above plot the suv category has highest partner_working and blue margin indicated Yes and Brown margin indicated No.So having a working partner leads to purchase of a higher priced car.

# %% [markdown]
# ### Q.H. The main objective of this analysis is to devise an improved marketing strategy to send targeted information to different groups of potential buyers present in the data. For the current analysis use the Gender and Marital_status - fields to arrive at groups with similar purchase history.

# %%
sns.barplot(data=df, x='Gender', y='Price');

# %%
sns.barplot(data=df, x='Marital_status', y='Price');

# %% [markdown]
# #### Insights:
# ##### The male who are single has the mimimum price of 35k.

# %% [markdown]
# # Problem 2

# %% [markdown]
# ### Analyze the dataset and list down the top 5 important variables, along with the business justifications.

# %%
path = ('godigt_cc_data (1).xlsx')
xl = pd.ExcelFile(path)
print(xl.sheet_names)
# Out:
# ['Sheet1', 'Sheet3']

# %%
df1 = xl.parse('Sheet1')

# %%
#Checking shape 
df1.shape
# Out:
# (8448, 28)

# %%
#Check for Null Values
df1.isnull().sum()
# Out:
# userid                      0
# card_no                     0
# card_bin_no                 0
# Issuer                      0
# card_type                   0
# card_source_date            0
# high_networth               0
# active_30                   0
# active_60                   0
# active_90                   0
# cc_active30                 0
# cc_active60                 0
# cc_active90                 0
# hotlist_flag                0
# widget_products             0
# engagement_products         0
# annual_income_at_source     0
# other_bank_cc_holding       0
# bank_vintage                0
# T+1_month_activity          0
# T+2_month_activity          0
# T+3_month_activity          0
# T+6_month_activity          0
# T+12_month_activity         0
# Transactor_revolver        38
# avg_spends_l3m              0
# Occupation_at_source        0
# cc_limit                    0
# dtype: int64

# %%
#Filling Null Values
df1['Transactor_revolver']= df1['Transactor_revolver'].fillna("NA")

# %%
df1.isnull().sum()
# Out:
# userid                     0
# card_no                    0
# card_bin_no                0
# Issuer                     0
# card_type                  0
# card_source_date           0
# high_networth              0
# active_30                  0
# active_60                  0
# active_90                  0
# cc_active30                0
# cc_active60                0
# cc_active90                0
# hotlist_flag               0
# widget_products            0
# engagement_products        0
# annual_income_at_source    0
# other_bank_cc_holding      0
# bank_vintage               0
# T+1_month_activity         0
# T+2_month_activity         0
# T+3_month_activity         0
# T+6_month_activity         0
# T+12_month_activity        0
# Transactor_revolver        0
# avg_spends_l3m             0
# Occupation_at_source       0
# cc_limit                   0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8448 entries, 0 to 8447
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   userid                   8448 non-null   int64
#  1   card_no                  8448 non-null   object
#  2   card_bin_no              8448 non-null   int64
#  3   Issuer                   8448 non-null   object
#  4   card_type                8448 non-null   object
#  5   card_source_date         8448 non-null   datetime64[ns]
#  6   high_networth            8448 non-null   object
#  7   active_30                8448 non-null   int64
#  8   active_60                8448 non-null   int64
#  9   active_90                8448 non-null   int64
#  10  cc_active30              8448 non-null   int64
#  11  cc_active60              8448 non-null   int64
#  12  cc_active90              8448 non-null   int64
#  13  hotlist_flag             8448 non-null   object
# ...

# %%
df1.head()
# Out:
#    userid              card_no  card_bin_no Issuer   card_type  \
# 0       1  4384 39XX XXXX XXXX       438439   Visa        edge
# 1       2  4377 48XX XXXX XXXX       437748   Visa  prosperity
# 2       3  4377 48XX XXXX XXXX       437748   Visa     rewards
# 3       4  4258 06XX XXXX XXXX       425806   Visa   indianoil
# 4       5  4377 48XX XXXX XXXX       437748   Visa        edge
#
#   card_source_date high_networth  active_30  active_60  active_90  ...  \
# 0       2019-09-29             B          0          1          1  ...
# 1       2002-10-30             A          1          1          1  ...
# 2       2013-10-05             C          0          0          0  ...
# 3       1999-06-01             E          0          1          1  ...
# 4       2006-06-13             B          1          1          1  ...
#
#    bank_vintage  T+1_month_activity  T+2_month_activity T+3_month_activity  \
# 0            27                   0                   0                  0
# ...

# %%
dups = df1.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 0

# %%
df1[['avg_spends_l3m','cc_limit']].describe()
# Out:
#        avg_spends_l3m       cc_limit
# count     8448.000000    8448.000000
# mean     49527.365530  251706.912879
# std      46244.954836  229114.856385
# min          0.000000       0.000000
# 25%      17110.000000   90000.000000
# 50%      37943.000000  150000.000000
# 75%      66095.750000  350000.000000
# max     289292.000000  990000.000000

# %% [markdown]
# #### Insights:
# ##### The cc_limit has the maximum value than the avg_spends_l3m.
# ##### The Increment of credit card limit has increased rapidly from 25% to 75%.

# %%
fig, axes = plt.subplots(nrows=2,ncols=2)
fig.set_size_inches(10,8)
sns.histplot(df1['avg_spends_l3m'], kde=True, ax=axes[0][0])
sns.boxplot(x='avg_spends_l3m', data=df1, ax=axes[0][1])
sns.histplot(df1['cc_limit'] , kde=True, ax=axes[1][0])
sns.boxplot(x='cc_limit', data=df1 , ax=axes[1][1])
plt.show()

# %% [markdown]
# #### Insights:
# ##### The avg_spends_l3m has decreasing rate over the increasing in spending rate.
# ##### The credit card limit has more increasing rate between 0 to 0.2.Rather than that it has a similar rate throught the end of the limit.
# ##### Both average spending and credit card limit has outliers in the upper values.

# %%
## Categorical Variable
sns.countplot(x='Occupation_at_source', data=df1, palette='pastel')
# Out:
# <AxesSubplot:xlabel='Occupation_at_source', ylabel='count'>

# %% [markdown]
# #### Insights:
# ##### The Salaried persons are occupied more than the remaining persons

# %% [markdown]
# ####  Bivariate Analysis

# %%
## Categorical vs Categorical

# %%
sns.countplot(x='Issuer', hue='Occupation_at_source', data=df1)
# Out:
# <AxesSubplot:xlabel='Issuer', ylabel='count'>

# %% [markdown]
# #### Insights:
# ##### The visa card type has the majority occupations while the Amex has the lowest occupations.

# %%
pd.crosstab(df1['Issuer'], df1['Occupation_at_source'], margins=True, normalize = True)
# Out:
# Occupation_at_source         0  Housewife   Retired  Salaried  Self Employed  \
# Issuer
# Amex                  0.002012   0.002367  0.004853  0.026160       0.012784
# Mastercard            0.003196   0.004143  0.009233  0.038234       0.024503
# Visa                  0.025687   0.038944  0.114820  0.399384       0.220170
# All                   0.030895   0.045455  0.128906  0.463778       0.257457
#
# Occupation_at_source   Student       All
# Issuer
# Amex                  0.004025  0.052202
# Mastercard            0.006866  0.086174
# Visa                  0.062618  0.861624
# All                   0.073509  1.000000

# %%
#### Insights:
##### 86.2% occupied with the Visa card.

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df1.corr(),annot=True,fmt=".2f");

# %% [markdown]
# #### Insights:
# ##### Highest correlation has taken place in the cc_limit to the active 30 to 90 and cc-active 30 to 90

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Scaling

# %%
## Dropping the ID fearure
df1.drop(labels='userid',axis=1,inplace=True)
df1.head()
# Out:
#                card_no  card_bin_no Issuer   card_type card_source_date  \
# 0  4384 39XX XXXX XXXX       438439   Visa        edge       2019-09-29
# 1  4377 48XX XXXX XXXX       437748   Visa  prosperity       2002-10-30
# 2  4377 48XX XXXX XXXX       437748   Visa     rewards       2013-10-05
# 3  4258 06XX XXXX XXXX       425806   Visa   indianoil       1999-06-01
# 4  4377 48XX XXXX XXXX       437748   Visa        edge       2006-06-13
#
#   high_networth  active_30  active_60  active_90  cc_active30  ...  \
# 0             B          0          1          1            0  ...
# 1             A          1          1          1            0  ...
# 2             C          0          0          0            0  ...
# 3             E          0          1          1            1  ...
# 4             B          1          1          1            0  ...
#
#    bank_vintage  T+1_month_activity T+2_month_activity  T+3_month_activity  \
# ...

# %%
df1.drop(labels='card_source_date',axis=1,inplace=True)
df1.head()
# Out:
#                card_no  card_bin_no Issuer   card_type high_networth  \
# 0  4384 39XX XXXX XXXX       438439   Visa        edge             B
# 1  4377 48XX XXXX XXXX       437748   Visa  prosperity             A
# 2  4377 48XX XXXX XXXX       437748   Visa     rewards             C
# 3  4258 06XX XXXX XXXX       425806   Visa   indianoil             E
# 4  4377 48XX XXXX XXXX       437748   Visa        edge             B
#
#    active_30  active_60  active_90  cc_active30  cc_active60  ...  \
# 0          0          1          1            0            0  ...
# 1          1          1          1            0            0  ...
# 2          0          0          0            0            0  ...
# 3          0          1          1            1            1  ...
# 4          1          1          1            0            1  ...
#
#    bank_vintage T+1_month_activity  T+2_month_activity  T+3_month_activity  \
# ...

# %%
cat=[]
num=[]
for i in df1.columns:
    if df1[i].dtype=="object":
        cat.append(i)
    else:
        num.append(i)
print(cat) 
print(num)
# Out:
# ['card_no', 'Issuer', 'card_type', 'high_networth', 'hotlist_flag', 'other_bank_cc_holding', 'Transactor_revolver', 'Occupation_at_source']
# ['card_bin_no', 'active_30', 'active_60', 'active_90', 'cc_active30', 'cc_active60', 'cc_active90', 'widget_products', 'engagement_products', 'annual_income_at_source', 'bank_vintage', 'T+1_month_activity', 'T+2_month_activity', 'T+3_month_activity', 'T+6_month_activity', 'T+12_month_activity', 'avg_spends_l3m', 'cc_limit']

# %%
### MinMax method
from sklearn.preprocessing import MinMaxScaler

# %%
# build the scaler model
scaler = MinMaxScaler().fit(df1[num])
# transform the test test
data_minmax = scaler.transform(df1[num])
data_minmax=pd.DataFrame(data_minmax, columns=df1[num].columns)
data_minmax.describe()
# Out:
#        card_bin_no    active_30    active_60    active_90  cc_active30  \
# count  8448.000000  8448.000000  8448.000000  8448.000000  8448.000000
# mean      0.406290     0.292377     0.494792     0.642045     0.284091
# std       0.207044     0.454881     0.500002     0.479427     0.451007
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.334947     0.000000     0.000000     0.000000     0.000000
# 50%       0.411749     0.000000     0.000000     1.000000     0.000000
# 75%       0.417779     1.000000     1.000000     1.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        cc_active60  cc_active90  widget_products  engagement_products  \
# count  8448.000000  8448.000000      8448.000000          8448.000000
# mean      0.484493     0.632339         0.516369             0.498890
# std       0.499789     0.482197         0.324742             0.321517
# ...

# %% [markdown]
# #### Insights
# ##### Min-Max method ensure that the data scaled to have values in the range 0 to 1

# %% [markdown]
# ### Label Encoding

# %%
df1[cat]
# Out:
#                   card_no Issuer   card_type high_networth hotlist_flag  \
# 0     4384 39XX XXXX XXXX   Visa        edge             B            N
# 1     4377 48XX XXXX XXXX   Visa  prosperity             A            N
# 2     4377 48XX XXXX XXXX   Visa     rewards             C            N
# 3     4258 06XX XXXX XXXX   Visa   indianoil             E            N
# 4     4377 48XX XXXX XXXX   Visa        edge             B            N
# ...                   ...    ...         ...           ...          ...
# 8443  4262 41XX XXXX XXXX   Visa   chartered             A            N
# 8444    37691 6XXXX XXXXX   Amex   centurion             A            N
# 8445  4375 51XX XXXX XXXX   Visa     rewards             D            N
# 8446  4477 47XX XXXX XXXX   Visa   indianoil             C            N
# 8447  4262 41XX XXXX XXXX   Visa     rewards             D            N
#
#      other_bank_cc_holding Transactor_revolver Occupation_at_source
# ...

# %%
# convert a column to a category, then use those category values for your label encoding:
df1["Issuer"] =df1["Issuer"].astype('category')
df1.dtypes
# Out:
# card_no                      object
# card_bin_no                   int64
# Issuer                     category
# card_type                    object
# high_networth                object
# active_30                     int64
# active_60                     int64
# active_90                     int64
# cc_active30                   int64
# cc_active60                   int64
# cc_active90                   int64
# hotlist_flag                 object
# widget_products               int64
# engagement_products           int64
# annual_income_at_source       int64
# other_bank_cc_holding        object
# bank_vintage                  int64
# T+1_month_activity            int64
# T+2_month_activity            int64
# T+3_month_activity            int64
# T+6_month_activity            int64
# T+12_month_activity           int64
# Transactor_revolver          object
# avg_spends_l3m                int64
# Occupation_at_source         object
# cc_limit                      int64
# ...

# %% [markdown]
# #### Insights:
# ##### Changing the label doesnot effect the card details of average spending
